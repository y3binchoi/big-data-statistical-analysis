# %% [markdown]
# ## Actor1의 첫번째 파일 읽고 실행해보기

# %%
import wave

# %%
import os

# %% [markdown]
# ### 캐글 연결하기
#
#
# https://www.kaggle.com/general/74235

# %%
# colab
# !pip install -q kaggle
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-0608dd90-b135-49db-9fc6-544559431748" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0608dd90-b135-49db-9fc6-544559431748">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                               title                                              size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# salvatorerastelli/spotify-and-youtube                             Spotify and Youtube                                 9MB  2023-03-20 15:43:25           7123        266  1.0
# ppb00x/country-gdp                                                Country_GDP                                         7KB  2023-04-07 06:47:36            732         26  1.0
# erdemtaha/cancer-data                                             Cancer Data                                        49KB  2023-03-22 07:57:00           2740         70  1.0
# ...

# %%
# !pwd
# Out:
# /content

# %%
# !mkdir train
# !ls -al
# Out:
# total 24
# drwxr-xr-x 1 root root 4096 Apr 17 05:12 .
# drwxr-xr-x 1 root root 4096 Apr 17 05:04 ..
# drwxr-xr-x 4 root root 4096 Apr 13 13:29 .config
# -rw-r--r-- 1 root root   63 Apr 17 05:10 kaggle.json
# drwxr-xr-x 1 root root 4096 Apr 13 13:30 sample_data
# drwxr-xr-x 2 root root 4096 Apr 17 05:12 train

# %%
# !kaggle datasets download -d uwrfkaggler/ravdess-emotional-speech-audio
# Out:
# ...
#  95% 409M/429M [00:03<00:00, 113MB/s]
# 100% 429M/429M [00:03<00:00, 141MB/s]

# %%
# !ls -al
# Out:
# total 439584
# drwxr-xr-x 1 root root      4096 Apr 17 05:12 .
# drwxr-xr-x 1 root root      4096 Apr 17 05:04 ..
# drwxr-xr-x 4 root root      4096 Apr 13 13:29 .config
# -rw-r--r-- 1 root root        63 Apr 17 05:10 kaggle.json
# -rw-r--r-- 1 root root 450102890 Apr 17 05:12 ravdess-emotional-speech-audio.zip
# drwxr-xr-x 1 root root      4096 Apr 13 13:30 sample_data
# drwxr-xr-x 2 root root      4096 Apr 17 05:12 train

# %%
! unzip ravdess-emotional-speech-audio.zip -d train
# Out:
# Archive:  ravdess-emotional-speech-audio.zip
#   inflating: train/Actor_01/03-01-01-01-01-01-01.wav
#   inflating: train/Actor_01/03-01-01-01-01-02-01.wav
#   inflating: train/Actor_01/03-01-01-01-02-01-01.wav
#   inflating: train/Actor_01/03-01-01-01-02-02-01.wav
#   inflating: train/Actor_01/03-01-02-01-01-01-01.wav
#   inflating: train/Actor_01/03-01-02-01-01-02-01.wav
#   inflating: train/Actor_01/03-01-02-01-02-01-01.wav
#   inflating: train/Actor_01/03-01-02-01-02-02-01.wav
#   inflating: train/Actor_01/03-01-02-02-01-01-01.wav
#   inflating: train/Actor_01/03-01-02-02-01-02-01.wav
#   inflating: train/Actor_01/03-01-02-02-02-01-01.wav
#   inflating: train/Actor_01/03-01-02-02-02-02-01.wav
#   inflating: train/Actor_01/03-01-03-01-01-01-01.wav
#   inflating: train/Actor_01/03-01-03-01-01-02-01.wav
#   inflating: train/Actor_01/03-01-03-01-02-01-01.wav
#   inflating: train/Actor_01/03-01-03-01-02-02-01.wav
#   inflating: train/Actor_01/03-01-03-02-01-01-01.wav
# ...

# %%
# os.chdir("D:/Bigdata/RAVDESS/Actor_01/")
os.chdir("./train/Actor_01/")
# !pwd
# Out:
# /content/train/Actor_01

# %%
# !ls -al
# Out:
# total 25364
# drwxr-xr-x  2 root root   4096 Apr 17 05:13 .
# drwxr-xr-x 27 root root   4096 Apr 17 05:13 ..
# -rw-r--r--  1 root root 375720 Oct 17  2019 03-01-01-01-01-01-01.wav
# -rw-r--r--  1 root root 379106 Oct 17  2019 03-01-01-01-01-02-01.wav
# -rw-r--r--  1 root root 372698 Oct 17  2019 03-01-01-01-02-01-01.wav
# -rw-r--r--  1 root root 363108 Oct 17  2019 03-01-01-01-02-02-01.wav
# -rw-r--r--  1 root root 399494 Oct 17  2019 03-01-02-01-01-01-01.wav
# -rw-r--r--  1 root root 751848 Oct 17  2019 03-01-02-01-01-02-01.wav
# -rw-r--r--  1 root root 396294 Oct 17  2019 03-01-02-01-02-01-01.wav
# -rw-r--r--  1 root root 393086 Oct 17  2019 03-01-02-01-02-02-01.wav
# -rw-r--r--  1 root root 415516 Oct 17  2019 03-01-02-02-01-01-01.wav
# -rw-r--r--  1 root root 444344 Oct 17  2019 03-01-02-02-01-02-01.wav
# -rw-r--r--  1 root root 463564 Oct 17  2019 03-01-02-02-02-01-01.wav
# -rw-r--r--  1 root root 444344 Oct 17  2019 03-01-02-02-02-02-01.wav
# ...

# %%
음성파일 = "03-01-01-01-01-01-01.wav"
음성1 = wave.open(음성파일, "r")

# %%
print(음성1.getnchannels())
print(음성1.getsampwidth())
print(음성1.getframerate())
print(음성1.getnframes())
print(음성1.getparams())
# Out:
# 1
# 2
# 48000
# 158558
# _wave_params(nchannels=1, sampwidth=2, framerate=48000, nframes=158558, comptype='NONE', compname='not compressed')

# %% [markdown]
# ## RAVDESS에 있는 음성파일을 하나의 리스트로 만듬
# ### 여러 음성파일을 처리할 때 파일명들을 하나의 리스트로 묶어 처리하면 편함

# %%
from glob import glob

# %%
# 음성묶음 = glob("D:/Bigdata/RAVDESS/*/*.wav")
음성묶음 = glob("/content/train/*/*.wav")
print(음성묶음[0])
# Out:
# /content/train/Actor_17/03-01-08-02-02-02-17.wav

# %%
print(*음성묶음, sep='\n')
# Out:
# /content/train/Actor_17/03-01-08-02-02-02-17.wav
# /content/train/Actor_17/03-01-01-01-02-02-17.wav
# /content/train/Actor_17/03-01-03-02-02-01-17.wav
# /content/train/Actor_17/03-01-05-01-01-02-17.wav
# /content/train/Actor_17/03-01-03-01-01-01-17.wav
# /content/train/Actor_17/03-01-07-01-02-01-17.wav
# /content/train/Actor_17/03-01-03-01-02-01-17.wav
# /content/train/Actor_17/03-01-06-02-01-01-17.wav
# /content/train/Actor_17/03-01-07-01-01-01-17.wav
# /content/train/Actor_17/03-01-05-01-02-02-17.wav
# /content/train/Actor_17/03-01-05-01-02-01-17.wav
# /content/train/Actor_17/03-01-01-01-01-02-17.wav
# /content/train/Actor_17/03-01-06-01-01-02-17.wav
# /content/train/Actor_17/03-01-08-01-02-02-17.wav
# /content/train/Actor_17/03-01-08-02-01-01-17.wav
# /content/train/Actor_17/03-01-06-01-02-01-17.wav
# /content/train/Actor_17/03-01-03-01-01-02-17.wav
# /content/train/Actor_17/03-01-08-01-02-01-17.wav
# /content/train/Actor_17/03-01-02-01-01-02-17.wav
# ...

# %%
from IPython.display import Audio, display

# %%
display(Audio(음성묶음[0]))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 첫 번째 리스트 값(음성파일)에 대해 시각적으로 표시해보기
# - 시계열 그림
# - spectrogram

# %%
! pip install matplot librosa seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 6.9 MB/s eta 0:00:00
# ...
#   Created wheel for SimpleWebSocketServer: filename=SimpleWebSocketServer-0.1.2-py3-none-any.whl size=9684 sha256=e0f4e5f7d2102deb79d7ff800065edd95137bf685d64e029dd02dae6f55041f3
#   Stored in directory: /root/.cache/pip/wheels/54/20/6b/a4ce68b72f26f10cdd3280976de363886c9172be1374666c3d
# ...

# %%
import pandas as pd 
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# 아래는 관리자 권한 명령 프롬프트에서 설치해야 함.

# %%
import seaborn as sns

# %%
import librosa

# %%
import librosa.display

# %%
sns.set_theme(style="white", palette=None)
color_pal = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
음성자료, 표집률 = librosa.load(음성묶음[0])

# %%
print(f'음성자료:{음성자료[:10]}')
# Out:
# 음성자료:[ 2.2323415e-05  3.2018026e-05  3.1273996e-06  8.9509376e-06
#   1.1804278e-05  7.9690517e-06 -7.7916866e-07  4.0339008e-05
#   2.0212447e-05  2.3200586e-05]

# %%
print(f'형태:{음성자료.shape}')
# Out:
# 형태:(77988,)

# %%
print(f'표집률:{표집률}') # 1초에22050개의 데이터
# Out:
# 표집률:22050

# %%
## 시계열 그림
pd.Series(음성자료).plot(figsize=(10,5), lw=1, title="Raw Audio Data", color=color_pal[0])
# Out:
# <Axes: title={'center': 'Raw Audio Data'}>

# %% [markdown]
# 그림이 중요한게 아니라
#
# 음성 자료를 이렇게 처리할 수 있다.
#
# 이렇게 얻은 판다스를 어떻게 처리할 것인가.

# %% [markdown]
# 값이 앞 뒤로 없다. 그 부분을 잘라보자.

# %%
유의음성, _ = librosa.effects.trim(음성자료, top_db=50)
pd.Series(유의음성).plot(figsize=(10,5), lw=1, title="Trimmed Sample Data", color=color_pal[1])
plt.show()

# %%
pd.Series(음성자료[30000:31000]).plot(figsize=(10,5), lw=1, title="Raw Audio Sample Data", color=color_pal[2])
plt.show()

# %% [markdown]
# ### Spectrogram
# - 다양한 형태의 주파수 공간 처리해보는 방법

# %%
변환자료 = librosa.stft(음성자료)
변환dB = librosa.amplitude_to_db(np.abs(변환자료),ref=np.max)
변환dB.shape
# Out:
# (1025, 143)

# %%
fig, ax = plt.subplots(figsize=(10,5))
이미지 = librosa.display.specshow(변환dB, x_axis="time", y_axis="log", ax=ax)
ax.set_title("Spectrogram example", fontsize = 20)
fig.colorbar(이미지,ax=ax, format=f'%0.1f')
plt.show()

# %%
from scipy.fft import fft,dct,ifft,idct
음성FFT=fft(음성자료).real
음성DCT=dct(음성자료, 1)
역음성FFT=ifft(음성FFT).real
역음성DCT=idct(음성DCT,  1)
